# %% [markdown]
# ## Purpose
#
# - Async pull latest kitties that are for sale with given price boundaries
# - Should I pull in lots of 2000? Then I can make predictions on! I think so
# - Should also combine the latest pull of id_s with pulling of traits
# - create df that is model ready (has latest trends and ETH price)
# - how to deal with get_dummies?
# - Need latest ETH TO USD
# - 80000000000000000 = 0.08 ETH (divide by 1000000000000000000)

# %%
import requests
import json
import pandas as pd
import codecs

# %%
ETH = pd.read_csv("../Data/ETH_price.csv")
ETH.head()
# Out:
#          date    open    high     low   close       volume    marketcap
# 0  2019-06-29  311.28  322.04  294.75  320.06  10929374565  34149263832
# 1  2019-06-28  294.14  313.03  292.94  311.23  11514656820  33202586960
# 2  2019-06-27  336.96  343.43  278.57  294.27  14038092503  31389390615
# 3  2019-06-26  317.99  361.40  315.95  336.75  16437084081  35916727561
# 4  2019-06-25  310.68  318.13  307.64  318.13   9641764965  33925713000

# %%
url = 'https://public.api.cryptokitties.co/v1/kitties?include=sale&price=80000000000000000-1000000000000000000&orderBy=current_price&limit=20&offset=53652&orderDirection=asc'
payload = {}
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
}

response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False)

parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "kitties": [
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "1814400000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2018-01-07 01:17:01+00",
#                 "id": 624145,
#                 "seller": {
#                     "address": "0x4f84165016be508ae9ce7da7a26625b688956090",
#                     "hasDapper": false
#                 },
#                 "start_price": "8000000000000000000",
#                 "start_time": "2017-12-17 01:17:01+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "*waves*! I'm #{name}. I'm a Spin Instructor  by day, and I like jump-roping by night. I once dreamed of being a Foreign Film Director. Now I can be found talking about how much I lift all day. Can't wait to eat wet food with you!",
#             "color": "limegreen",
#             "created_at": "2017-12-05T06:52:09Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "munchkin",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "body"
#                 },
#                 {
#                     "description": "limegreen",
#                     "kittyId": 3010,
#                     "position": 1,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "crazy",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "totesbasic",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "pouty",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "orangesoda",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "coffee",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "kittencream",
#                     "kittyId": 82461,
#                     "position": -1,
#                     "type": "colortertiary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 12,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x7530a404d3373364fcd38aa672fadfae7f56fc20",
#                 "hasDapper": false,
#                 "image": "13",
#                 "nickname": "VB"
#             },
#             "id": 82461,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/82461.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/82461.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/82461.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "limegreen",
#                 "created_at": "2017-12-04T22:04:55Z",
#                 "generation": 11,
#                 "id": 69557,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/69557.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/69557.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/69557.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "G11 Max out",
#                 "owner": {
#                     "address": "0x7530a404d3373364fcd38aa672fadfae7f56fc20",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517478954841,
#                     "cooldown_index": 7,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Brisk. Bred Once",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 1,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "mintgreen",
#                 "created_at": "2017-12-05T01:19:19Z",
#                 "generation": 11,
#                 "id": 74806,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/74806.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/74806.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/74806.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Bred Once. was brisk",
#                 "owner": {
#                     "address": "0x7530a404d3373364fcd38aa672fadfae7f56fc20",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517342626318,
#                     "cooldown_index": 6,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1517591949400,
#                 "cooldown_index": 7,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2017-12-16 08:25:04+00",
#                 "id": 649888,
#                 "seller": {
#                     "address": "0x89a21f5f5c778a73618d9da1235d31e2b2dda003",
#                     "hasDapper": false
#                 },
#                 "start_price": "1200000000000000000",
#                 "start_time": "2017-12-14 08:25:04+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Yo! I'm #{name}. In high school, I was voted biggest teacher's pet. In my free time, I can usually be found tantalizing or tricking babies. I can't wait to wake you up at 4am for seemingly no reason.",
#             "color": "mintgreen",
#             "created_at": "2017-12-14T06:09:28Z",
#             "enhanced_cattributes": [],
#             "fancy_ranking": 4865,
#             "fancy_type": "DuCat",
#             "generation": 6,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x89a21f5f5c778a73618d9da1235d31e2b2dda003",
#                 "hasDapper": false,
#                 "image": "15",
#                 "nickname": "Workzone"
#             },
#             "id": 302688,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/302688.png",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/302688.png",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/302688.png",
#             "is_exclusive": false,
#             "is_fancy": true,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "mintgreen",
#                 "created_at": "2017-12-12T09:34:36Z",
#                 "fancy_type": "DuCat",
#                 "generation": 5,
#                 "id": 267061,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/267061.png",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/267061.png",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/267061.png",
#                 "is_exclusive": false,
#                 "is_fancy": true,
#                 "language": "en",
#                 "name": "Felcor",
#                 "owner": {
#                     "address": "0x5fc196df0bf0e21c80d5855af780b2d2bae0170a",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517501090121,
#                     "cooldown_index": 7,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": null,
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 1,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "topaz",
#                 "created_at": "2017-12-14T05:13:41Z",
#                 "generation": 4,
#                 "id": 301884,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/301884.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/301884.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/301884.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "owner": {
#                     "address": "0x89a21f5f5c778a73618d9da1235d31e2b2dda003",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1516154574093,
#                     "cooldown_index": 5,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1450941913477,
#                 "cooldown_index": 3,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2019-05-20 20:07:17+00",
#                 "id": 2210245,
#                 "seller": {
#                     "address": "0x166814bb16aab1f538ce5bc5762d1bb11275dc2c",
#                     "hasDapper": true
#                 },
#                 "start_price": "1000000000000000000",
#                 "start_time": "2019-05-18 20:07:17+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Sup playa, my name is #{name}, but I'll also respond to Morrissey. I'd give anything to hang out with Elijah Wood. Let's get matching Karen Walker tattoos.",
#             "color": "thundergrey",
#             "created_at": "2018-12-07T14:19:34Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "whixtensions",
#                     "kittyId": 1268190,
#                     "position": 11301,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "vigilante",
#                     "kittyId": 1268190,
#                     "position": 662,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "savannah",
#                     "kittyId": 1268190,
#                     "position": 9424,
#                     "type": "body"
#                 },
#                 {
#                     "description": "cyborg",
#                     "kittyId": 1268190,
#                     "position": 417,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "swarley",
#                     "kittyId": 1268190,
#                     "position": 5921,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "shadowgrey",
#                     "kittyId": 1268190,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "belleblue",
#                     "kittyId": 1268190,
#                     "position": 9576,
#                     "type": "colortertiary"
#                 },
#                 {
#                     "description": "thundergrey",
#                     "kittyId": 1268190,
#                     "position": 8191,
#                     "type": "coloreyes"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 11,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x0de69b30c7c2fe14276dda312f4de3231dfa34f8",
#                 "hasDapper": false,
#                 "image": "19",
#                 "nickname": "polypaws2"
#             },
#             "id": 1268190,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1268190.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1268190.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1268190.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "sapphire",
#                 "created_at": "2018-12-07T03:23:39Z",
#                 "generation": 10,
#                 "id": 1266784,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1266784.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1266784.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1266784.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Chantrea Snookysimmons",
#                 "owner": {
#                     "address": "0x166814bb16aab1f538ce5bc5762d1bb11275dc2c",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1546201635313,
#                     "cooldown_index": 8,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Gene Glitch! Father Wasabieyes",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "olive",
#                 "created_at": "2018-12-06T04:02:45Z",
#                 "generation": 9,
#                 "id": 1263535,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1263535.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1263535.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1263535.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Loki Softgoo",
#                 "owner": {
#                     "address": "0x166814bb16aab1f538ce5bc5762d1bb11275dc2c",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1546226022187,
#                     "cooldown_index": 9,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1457452677976,
#                 "cooldown_index": 5,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2018-10-22 05:26:05+00",
#                 "id": 1903243,
#                 "seller": {
#                     "address": "0x8abda881c2009f4de8688de9fdb7c03d5681df47",
#                     "hasDapper": false
#                 },
#                 "start_price": "1000000000000000000",
#                 "start_time": "2018-10-20 05:26:05+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "*deadpan stare*. My parents named me #{name}, but I prefer Barack Obama. Would you believe me if I told you that dogs are robot aliens who plan to take over Earth? What if I said the world is flat? Will you brush my tail? I like it brushed three times a day.",
#             "color": "mintgreen",
#             "created_at": "2018-10-19T16:47:43Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "dali",
#                     "kittyId": 1107384,
#                     "position": 2798,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "amur",
#                     "kittyId": 472740,
#                     "position": 1703,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "wonky",
#                     "kittyId": 472740,
#                     "position": 694,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "bobtail",
#                     "kittyId": 521149,
#                     "position": 270,
#                     "type": "body"
#                 },
#                 {
#                     "description": "hintomint",
#                     "kittyId": 669191,
#                     "position": 741,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "apricot",
#                     "kittyId": 626901,
#                     "position": 1116,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "sandalwood",
#                     "kittyId": 474252,
#                     "position": 1413,
#                     "type": "colortertiary"
#                 },
#                 {
#                     "description": "mintgreen",
#                     "kittyId": 1107384,
#                     "position": -1,
#                     "type": "coloreyes"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 3,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x8abda881c2009f4de8688de9fdb7c03d5681df47",
#                 "hasDapper": false,
#                 "image": "6",
#                 "nickname": "{S!R} Rage"
#             },
#             "id": 1107384,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1107384.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1107384.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1107384.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "mintgreen",
#                 "created_at": "2018-03-04T21:04:54Z",
#                 "generation": 2,
#                 "id": 584714,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/584714.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/584714.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/584714.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Lilacitty",
#                 "owner": {
#                     "address": "0x8abda881c2009f4de8688de9fdb7c03d5681df47",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1554610833332,
#                     "cooldown_index": 13,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Hintomint Apricot Dali",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 1,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "coralsunrise",
#                 "created_at": "2018-04-07T23:06:47Z",
#                 "generation": 2,
#                 "id": 669191,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/669191.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/669191.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/669191.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "ChartreuxR1 First G2 Hinto Jag",
#                 "owner": {
#                     "address": "0x8abda881c2009f4de8688de9fdb7c03d5681df47",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1554648364772,
#                     "cooldown_index": 13,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1454190004221,
#                 "cooldown_index": 1,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2017-12-06 12:00:46+00",
#                 "id": 3815,
#                 "seller": {
#                     "address": "0x1bbd7a11a477bd8007986ad89eac7aa04bbfc609",
#                     "hasDapper": false
#                 },
#                 "start_price": "500000000000000000",
#                 "start_time": "2017-12-04 12:00:46+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Heyo! I'm #{name}. I believe the world is flat. I once got in a fight with a rooster, and won. Let's get busy!",
#             "color": "strawberry",
#             "created_at": "2017-11-25T07:19:44Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "ragamuffin",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "body"
#                 },
#                 {
#                     "description": "strawberry",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "raisedbrow",
#                     "kittyId": 3068,
#                     "position": 5,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "luckystripe",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "beard",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "salmon",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "coffee",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "granitegrey",
#                     "kittyId": 6659,
#                     "position": -1,
#                     "type": "colortertiary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 8,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0xd50db15c1d9e96c4aa675d7959026c02d9667755",
#                 "hasDapper": false,
#                 "image": "6",
#                 "nickname": "snow"
#             },
#             "id": 6659,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/6659.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/6659.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/6659.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "strawberry",
#                 "created_at": "2017-11-24T10:37:23Z",
#                 "generation": 7,
#                 "id": 4732,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/4732.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/4732.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/4732.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Sailor gene",
#                 "owner": {
#                     "address": "0xd50db15c1d9e96c4aa675d7959026c02d9667755",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517906147408,
#                     "cooldown_index": 13,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": null,
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "strawberry",
#                 "created_at": "2017-11-24T00:45:19Z",
#                 "generation": 5,
#                 "id": 3504,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/3504.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/3504.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/3504.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Jeff Koons cat",
#                 "owner": {
#                     "address": "0xd50db15c1d9e96c4aa675d7959026c02d9667755",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517791238778,
#                     "cooldown_index": 10,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1517621118268,
#                 "cooldown_index": 5,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "432000000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2018-06-30 09:02:26+00",
#                 "id": 1659337,
#                 "seller": {
#                     "address": "0x5edb55e97bfe0dbdd3210d11f84a0cf8ea62d0c0",
#                     "hasDapper": false
#                 },
#                 "start_price": "500000000000000000",
#                 "start_time": "2018-06-25 09:02:26+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Bonjour. I'm known as #{name}. I have a complicated past, but I'm ready for a new beginning. I'm one of the few kitties that can eat eggplant using only my toes. Can I have your watch?",
#             "color": "thundergrey",
#             "created_at": "2018-06-22T17:38:15Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "thundergrey",
#                     "kittyId": 658050,
#                     "position": 2444,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "grim",
#                     "kittyId": 485766,
#                     "position": 912,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "slyboots",
#                     "kittyId": 735399,
#                     "position": 2915,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "ganado",
#                     "kittyId": 817224,
#                     "position": 3664,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "birman",
#                     "kittyId": 539079,
#                     "position": 936,
#                     "type": "body"
#                 },
#                 {
#                     "description": "barkbrown",
#                     "kittyId": 809092,
#                     "position": 6112,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "sandalwood",
#                     "kittyId": 720173,
#                     "position": 3563,
#                     "type": "colortertiary"
#                 },
#                 {
#                     "description": "cinderella",
#                     "kittyId": 770327,
#                     "position": 1168,
#                     "type": "colorprimary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 4,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x5edb55e97bfe0dbdd3210d11f84a0cf8ea62d0c0",
#                 "hasDapper": false,
#                 "image": "9",
#                 "nickname": "sule"
#             },
#             "id": 817224,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817224.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817224.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817224.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "cyan",
#                 "created_at": "2018-06-20T06:54:21Z",
#                 "generation": 3,
#                 "id": 812562,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/812562.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/812562.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/812562.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "owner": {
#                     "address": "0x5edb55e97bfe0dbdd3210d11f84a0cf8ea62d0c0",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1532950261122,
#                     "cooldown_index": 2,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": null,
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "thundergrey",
#                 "created_at": "2018-06-22T16:46:25Z",
#                 "generation": 3,
#                 "id": 817087,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817087.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817087.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/817087.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "owner": {
#                     "address": "0xc7af99fe5513eb6710e6d5f44f9989da40f27f26",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1532837860240,
#                     "cooldown_index": 2,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1532839517024,
#                 "cooldown_index": 3,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2017-12-12 16:08:24+00",
#                 "id": 437836,
#                 "seller": {
#                     "address": "0xda1df4b403d1557c54a2ee3aa28eaa5fc4af2ee7",
#                     "hasDapper": false
#                 },
#                 "start_price": "1350000000000000000",
#                 "start_time": "2017-12-10 16:08:24+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Oh hi! I'm #{name}. I enjoy sitting on your computer, reading garfield, and staying woke. It wasn't heavily publicized, but I once had a brief relationship with Snagglepuss. We're so fur-tunate to have found each other!",
#             "color": "topaz",
#             "created_at": "2017-12-10T00:25:15Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "munchkin",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "body"
#                 },
#                 {
#                     "description": "topaz",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "simple",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "luckystripe",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "pouty",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "greymatter",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "chocolate",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "granitegrey",
#                     "kittyId": 197184,
#                     "position": -1,
#                     "type": "colortertiary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 7,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0xda1df4b403d1557c54a2ee3aa28eaa5fc4af2ee7",
#                 "hasDapper": false,
#                 "image": "19",
#                 "nickname": "NouCat"
#             },
#             "id": 197184,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/197184.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/197184.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/197184.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "strawberry",
#                 "created_at": "2017-12-07T20:23:19Z",
#                 "generation": 6,
#                 "id": 135443,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/135443.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/135443.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/135443.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Lonely Kitty",
#                 "owner": {
#                     "address": "0xda1df4b403d1557c54a2ee3aa28eaa5fc4af2ee7",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1518525387941,
#                     "cooldown_index": 5,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Rare & one of a kind Kittypie",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "topaz",
#                 "created_at": "2017-12-03T22:41:04Z",
#                 "generation": 5,
#                 "id": 47753,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/47753.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/47753.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/47753.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Green Striped Squirrel",
#                 "owner": {
#                     "address": "0xda1df4b403d1557c54a2ee3aa28eaa5fc4af2ee7",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517333084088,
#                     "cooldown_index": 11,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1454718925727,
#                 "cooldown_index": 3,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2017-12-08 03:30:27+00",
#                 "id": 178218,
#                 "seller": {
#                     "address": "0x442623aa198be020e41a1ab7602729b506566435",
#                     "hasDapper": false
#                 },
#                 "start_price": "1500000000000000000",
#                 "start_time": "2017-12-06 03:30:27+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Good day! I'm #{name}. I'm a professional Foreign Film Director and I love hamburgers. I once pranced with a dog. I don't like to talk about it. I hope you like kitten around as much as I do!",
#             "color": "gold",
#             "created_at": "2017-12-05T20:36:30Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "sphynx",
#                     "kittyId": 93593,
#                     "position": -1,
#                     "type": "body"
#                 },
#                 {
#                     "description": "gold",
#                     "kittyId": 25392,
#                     "position": 1,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "raisedbrow",
#                     "kittyId": 14339,
#                     "position": 200,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "spock",
#                     "kittyId": 28444,
#                     "position": 102,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "saycheese",
#                     "kittyId": 11854,
#                     "position": 24,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "shadowgrey",
#                     "kittyId": 93593,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "chocolate",
#                     "kittyId": 93593,
#                     "position": -1,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "granitegrey",
#                     "kittyId": 93593,
#                     "position": -1,
#                     "type": "colortertiary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 10,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x442623aa198be020e41a1ab7602729b506566435",
#                 "hasDapper": false,
#                 "image": "1",
#                 "nickname": "CyKy"
#             },
#             "id": 93593,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/93593.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/93593.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/93593.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "mintgreen",
#                 "created_at": "2017-12-05T10:13:53Z",
#                 "generation": 9,
#                 "id": 85670,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/85670.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/85670.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/85670.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Bearded Chartreux Superstar",
#                 "owner": {
#                     "address": "0xda409a21279ac9fd141d497b4158954ef5380a8f",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517733182520,
#                     "cooldown_index": 10,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Spock's Golden Whisker",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "gold",
#                 "created_at": "2017-12-04T02:12:39Z",
#                 "generation": 4,
#                 "id": 51767,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/51767.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/51767.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/51767.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Gold Spock",
#                 "owner": {
#                     "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517217389181,
#                     "cooldown_index": 8,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1517618618677,
#                 "cooldown_index": 6,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "86400000000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2020-11-06 19:48:07+00",
#                 "id": 212509,
#                 "seller": {
#                     "address": "0xc0e93c6baa4fbff52f77d98b194d7246f6b2b35d",
#                     "hasDapper": false
#                 },
#                 "start_price": "1000000000000000000",
#                 "start_time": "2018-02-10 19:48:07+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Hey cutie! I'm #{name}. My friends describe me as tantalizing and seductive. I like to listen to Beyonc\u00e9 while grooming. Don't judge me. I hope we can be pawmates.",
#             "color": "mintgreen",
#             "created_at": "2017-12-05T23:53:36Z",
#             "enhanced_cattributes": [
#                 {
#                     "description": "munchkin",
#                     "kittyId": 97881,
#                     "position": -1,
#                     "type": "body"
#                 },
#                 {
#                     "description": "mintgreen",
#                     "kittyId": 97881,
#                     "position": -1,
#                     "type": "coloreyes"
#                 },
#                 {
#                     "description": "raisedbrow",
#                     "kittyId": 3002,
#                     "position": 1,
#                     "type": "eyes"
#                 },
#                 {
#                     "description": "calicool",
#                     "kittyId": 3420,
#                     "position": 9,
#                     "type": "pattern"
#                 },
#                 {
#                     "description": "tongue",
#                     "kittyId": 3020,
#                     "position": 1,
#                     "type": "mouth"
#                 },
#                 {
#                     "description": "greymatter",
#                     "kittyId": 97881,
#                     "position": -1,
#                     "type": "colorprimary"
#                 },
#                 {
#                     "description": "chocolate",
#                     "kittyId": 97881,
#                     "position": -1,
#                     "type": "colorsecondary"
#                 },
#                 {
#                     "description": "granitegrey",
#                     "kittyId": 97881,
#                     "position": -1,
#                     "type": "colortertiary"
#                 }
#             ],
#             "fancy_ranking": null,
#             "fancy_type": null,
#             "generation": 13,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0x3ddd2e9c22ccafb3c6dddbe096f38af4adcffc5e",
#                 "hasDapper": false,
#                 "image": "17",
#                 "nickname": "BradReardon"
#             },
#             "id": 97881,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/97881.svg",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/97881.svg",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/97881.png",
#             "is_exclusive": false,
#             "is_fancy": false,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "mintgreen",
#                 "created_at": "2017-12-05T07:57:01Z",
#                 "generation": 12,
#                 "id": 83422,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/83422.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/83422.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/83422.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "G12 CaliCool (RARE)",
#                 "owner": {
#                     "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1517958449826,
#                     "cooldown_index": 10,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "G13 CaliCool Tongue (RARE)",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "strawberry",
#                 "created_at": "2017-12-02T17:47:26Z",
#                 "generation": 12,
#                 "id": 30804,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/30804.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/30804.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/30804.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "B.O.B.",
#                 "owner": {
#                     "address": "0x4f21c6cc2260e54738597fe1bc3921a91b6e7398",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1518589261095,
#                     "cooldown_index": 13,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1517775622656,
#                 "cooldown_index": 9,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         },
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "172800000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2019-03-05 21:57:27+00",
#                 "id": 2248116,
#                 "seller": {
#                     "address": "0xfc624f8f58db41bdb95aedee1de3c1cf047105f1",
#                     "hasDapper": false
#                 },
#                 "start_price": "1000000000000000000",
#                 "start_time": "2019-03-03 21:57:27+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Did you hear a sound? Did you make one? Did you call for the vengeance of #{name}? I defeated the aphids devouring Mrs. Tigger\u2019s roses. I rescued the missing Kitteh from the park. I returned the stolen yak milk to a grateful yak. I am the justice, the answer, the righteous cause. Look for me in the wind.",
#             "color": "doridnudibranch",
#             "created_at": "2019-03-03T07:44:17Z",
#             "enhanced_cattributes": [],
#             "fancy_ranking": 16,
#             "fancy_type": "Glasswalker",
#             "generation": 6,
#             "hatched": true,
#             "hatcher": {
#                 "address": "0xfc624f8f58db41bdb95aedee1de3c1cf047105f1",
#                 "hasDapper": false,
#                 "image": "6",
#                 "nickname": "Accepting Offers @ Derek@7051@disc"
#             },
#             "id": 1427488,
#             "image_path": "",
#             "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427488.png",
#             "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427488.png",
#             "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427488.png",
#             "is_exclusive": false,
#             "is_fancy": true,
#             "is_prestige": false,
#             "is_special_edition": false,
#             "language": "en",
#             "matron": {
#                 "color": "dahlia",
#                 "created_at": "2019-03-03T06:34:13Z",
#                 "generation": 5,
#                 "id": 1427271,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427271.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427271.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1427271.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Sugar Ughkey",
#                 "owner": {
#                     "address": "0xfc624f8f58db41bdb95aedee1de3c1cf047105f1",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1552471984328,
#                     "cooldown_index": 12,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "name": "Glasswalker",
#             "offer": {
#                 "accepted": false,
#                 "approved": false,
#                 "bidder_address": "",
#                 "eth_price": 0,
#                 "expires_at": null,
#                 "id": "",
#                 "rejected": true,
#                 "status": ""
#             },
#             "owner": {
#                 "address": "0xb1690c08e213a35ed9bab7b318de14420fb57d8c",
#                 "hasDapper": false
#             },
#             "prestige_ranking": null,
#             "prestige_time_limit": null,
#             "prestige_type": null,
#             "purrs": {
#                 "count": 0,
#                 "is_purred": false
#             },
#             "sire": {
#                 "color": "doridnudibranch",
#                 "created_at": "2019-03-03T03:27:41Z",
#                 "generation": 5,
#                 "id": 1426752,
#                 "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1426752.svg",
#                 "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1426752.svg",
#                 "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1426752.png",
#                 "is_exclusive": false,
#                 "is_fancy": false,
#                 "language": "en",
#                 "name": "Muschi Hulanana",
#                 "owner": {
#                     "address": "0xfc624f8f58db41bdb95aedee1de3c1cf047105f1",
#                     "hasDapper": false
#                 },
#                 "status": {
#                     "cooldown": 1552874603150,
#                     "cooldown_index": 13,
#                     "is_gestating": false,
#                     "is_ready": true
#                 }
#             },
#             "status": {
#                 "cooldown": 1458262074080,
#                 "cooldown_index": 3,
#                 "is_gestating": false,
#                 "is_ready": true
#             },
#             "tricks": [],
#             "watchlist": {
#                 "count": 0,
#                 "is_watchlisted": false
#             }
#         }
#     ],
#     "limit": 20,
#     "offset": 53652,
#     "total": 53662
# }

# %%
all_urls = []
for i in range(int(53662/100)+ 2):
    all_urls.append(f'https://public.api.cryptokitties.co/v1/kitties?include=sale&price=80000000000000000-1000000000000000000&orderBy=current_price&limit={100}&offset={i*100}&orderDirection=asc')

# %%
import aiofiles
import os
import asyncio
import nest_asyncio
nest_asyncio.apply()
import aiohttp


payload = {}
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
}

async def download_html(session, url):
    async with session.request('GET', url, headers = headers, data = payload, allow_redirects=False) as res:
        filename = f'html/output_{len(os.listdir("html/"))}.html'
        print(len(os.listdir("./html")), end = "\r")
        async with aiofiles.open(filename, 'wb') as f:
            while True:
                chunk = await res.content.read(1024)
                if not chunk:
                    break
                await f.write(chunk)

        return await res.release()
    
async def main(url):
    connector = aiohttp.TCPConnector(limit=60)
    async with aiohttp.ClientSession(connector=connector) as session: #aiohttp.ClientSession()
        await download_html(session, url)

# urls = ['https://public.api.cryptokitties.co/v1/kitties/' + str(i) for i in range(100)] # a big list of websites to scrape

for i in range(int(len(all_urls)/10)+ 1):
    urls = all_urls[i*10: i*10 + 10]
    print('step: ' + str(i) + '   Number of files: ' + str(len(os.listdir("html/"))))
    loop = asyncio.get_event_loop()
    loop.run_until_complete(
        asyncio.gather(*(main(url) for url in urls))
    )
# Out:
# step: 0   Number of files: 1
# step: 1   Number of files: 11
# step: 2   Number of files: 21
# step: 3   Number of files: 31
# step: 4   Number of files: 41
# step: 5   Number of files: 51
# step: 6   Number of files: 61
# step: 7   Number of files: 71
# step: 8   Number of files: 81
# step: 9   Number of files: 91
# step: 10   Number of files: 101
# step: 11   Number of files: 111
# step: 12   Number of files: 121
# step: 13   Number of files: 130
# step: 14   Number of files: 140
# step: 15   Number of files: 150
# step: 16   Number of files: 160
# step: 17   Number of files: 170
# step: 18   Number of files: 180
# step: 19   Number of files: 190
# step: 20   Number of files: 200
# step: 21   Number of files: 210
# step: 22   Number of files: 220
# step: 23   Number of files: 230
# step: 24   Number of files: 240
# step: 25   Number of files: 250
# step: 26   Number of files: 260
# step: 27   Number of files: 270
# step: 28   Number of files: 280
# step: 29   Number of files: 290
# step: 30   Number of files: 300
# step: 31   Number of files: 310
# step: 32   Number of files: 320
# step: 33   Number of files: 330
# step: 34   Number of files: 340
# step: 35   Number of files: 350
# step: 36   Number of files: 360
# step: 37   Number of files: 370
# step: 38   Number of files: 380
# step: 39   Number of files: 390
# step: 40   Number of files: 400
# step: 41   Number of files: 410
# step: 42   Number of files: 420
# step: 43   Number of files: 430
# step: 44   Number of files: 440
# step: 45   Number of files: 450
# step: 46   Number of files: 460
# step: 47   Number of files: 470
# step: 48   Number of files: 480
# step: 49   Number of files: 490
# step: 50   Number of files: 500
# step: 51   Number of files: 510
# step: 52   Number of files: 520
# step: 53   Number of files: 530

# %% [markdown]
# ### ERROR HANDLING!

# %%
errors = []
for i in os.listdir("html/"):
    file = codecs.open("html/" + str(i), 'r',  encoding="utf8")
    parsed = json.loads(file.read())
    
    try:
        parsed['code']
        print(i)
        errors.append(i)
    except:
        pass
# Out:
# output_1.html
# output_330.html
# output_352.html
# output_355.html
# output_6.html

# %%
payload = {}
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
}

for e in errors:
    limit = 100
    offset = (int(e[7:].split(".")[0])-1)*100

    url = f'https://public.api.cryptokitties.co/v1/kitties?include=sale&price=80000000000000000-1000000000000000000&orderBy=current_price&limit={100}&offset={offset}&orderDirection=asc'
    response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False).text

    file = open("html/" + e, 'w', encoding="utf-8")
    file.write(response)
    file.close()

    print(e)
# Out:
# output_537.html

# %%
def sorting(val): 
    return (int(val[7:].split(".")[0])-1)  

dirs = sorted(os.listdir("html/"), key = sorting)
dirs
# Out:
# ['output_1.html',
#  'output_2.html',
#  'output_3.html',
#  'output_4.html',
#  'output_5.html',
#  'output_6.html',
#  'output_7.html',
#  'output_8.html',
#  'output_9.html',
#  'output_10.html',
#  'output_11.html',
#  'output_12.html',
#  'output_13.html',
#  'output_14.html',
#  'output_15.html',
#  'output_16.html',
#  'output_17.html',
#  'output_18.html',
#  'output_19.html',
#  'output_20.html',
#  'output_21.html',
#  'output_22.html',
#  'output_23.html',
#  'output_24.html',
#  'output_25.html',
#  'output_26.html',
#  'output_27.html',
#  'output_28.html',
#  'output_29.html',
#  'output_30.html',
#  'output_31.html',
#  'output_32.html',
#  'output_33.html',
#  'output_34.html',
#  'output_35.html',
#  'output_36.html',
#  'output_37.html',
#  'output_38.html',
#  'output_39.html',
#  'output_40.html',
#  'output_41.html',
#  'output_42.html',
#  'output_43.html',
#  'output_44.html',
#  'output_45.html',
#  'output_46.html',
#  'output_47.html',
#  'output_48.html',
#  'output_49.html',
#  'output_50.html',
#  'output_51.html',
#  'output_52.html',
#  'output_53.html',
#  'output_54.html',
#  'output_55.html',
#  'output_56.html',
#  'output_57.html',
#  'output_58.html',
#  'output_59.html',
#  'output_60.html',
#  'output_61.html',
#  'output_62.html',
#  'output_63.html',
#  'output_64.html',
#  'output_65.html',
#  'output_66.html',
#  'output_67.html',
#  'output_68.html',
#  'output_69.html',
#  'output_70.html',
#  'output_71.html',
#  'output_72.html',
#  'output_73.html',
#  'output_74.html',
#  'output_75.html',
#  'output_76.html',
#  'output_77.html',
#  'output_78.html',
#  'output_79.html',
#  'output_80.html',
#  'output_81.html',
#  'output_82.html',
#  'output_83.html',
#  'output_84.html',
#  'output_85.html',
#  'output_86.html',
#  'output_87.html',
#  'output_88.html',
#  'output_89.html',
#  'output_90.html',
#  'output_91.html',
#  'output_92.html',
#  'output_93.html',
#  'output_94.html',
#  'output_95.html',
#  'output_96.html',
#  'output_97.html',
#  'output_98.html',
#  'output_99.html',
#  'output_100.html',
#  'output_101.html',
#  'output_102.html',
#  'output_103.html',
#  'output_104.html',
#  'output_105.html',
#  'output_106.html',
#  'output_107.html',
#  'output_108.html',
#  'output_109.html',
#  'output_110.html',
#  'output_111.html',
#  'output_112.html',
#  'output_113.html',
#  'output_114.html',
#  'output_115.html',
#  'output_116.html',
#  'output_117.html',
#  'output_118.html',
#  'output_119.html',
#  'output_120.html',
#  'output_121.html',
#  'output_122.html',
#  'output_123.html',
#  'output_124.html',
#  'output_125.html',
#  'output_126.html',
#  'output_127.html',
#  'output_128.html',
#  'output_129.html',
#  'output_130.html',
#  'output_131.html',
#  'output_132.html',
#  'output_133.html',
#  'output_134.html',
#  'output_135.html',
#  'output_136.html',
#  'output_137.html',
#  'output_138.html',
#  'output_139.html',
#  'output_140.html',
#  'output_141.html',
#  'output_142.html',
#  'output_143.html',
#  'output_144.html',
#  'output_145.html',
#  'output_146.html',
#  'output_147.html',
#  'output_148.html',
#  'output_149.html',
#  'output_150.html',
#  'output_151.html',
#  'output_152.html',
#  'output_153.html',
#  'output_154.html',
#  'output_155.html',
#  'output_156.html',
#  'output_157.html',
#  'output_158.html',
#  'output_159.html',
#  'output_160.html',
#  'output_161.html',
#  'output_162.html',
#  'output_163.html',
#  'output_164.html',
#  'output_165.html',
#  'output_166.html',
#  'output_167.html',
#  'output_168.html',
#  'output_169.html',
#  'output_170.html',
#  'output_171.html',
#  'output_172.html',
#  'output_173.html',
#  'output_174.html',
#  'output_175.html',
#  'output_176.html',
#  'output_177.html',
#  'output_178.html',
#  'output_179.html',
#  'output_180.html',
#  'output_181.html',
#  'output_182.html',
#  'output_183.html',
#  'output_184.html',
#  'output_185.html',
#  'output_186.html',
#  'output_187.html',
#  'output_188.html',
#  'output_189.html',
#  'output_190.html',
#  'output_191.html',
#  'output_192.html',
#  'output_193.html',
#  'output_194.html',
#  'output_195.html',
#  'output_196.html',
#  'output_197.html',
#  'output_198.html',
#  'output_199.html',
#  'output_200.html',
#  'output_201.html',
#  'output_202.html',
#  'output_203.html',
#  'output_204.html',
#  'output_205.html',
#  'output_206.html',
#  'output_207.html',
#  'output_208.html',
#  'output_209.html',
#  'output_210.html',
#  'output_211.html',
#  'output_212.html',
#  'output_213.html',
#  'output_214.html',
#  'output_215.html',
#  'output_216.html',
#  'output_217.html',
#  'output_218.html',
#  'output_219.html',
#  'output_220.html',
#  'output_221.html',
#  'output_222.html',
#  'output_223.html',
#  'output_224.html',
#  'output_225.html',
#  'output_226.html',
#  'output_227.html',
#  'output_228.html',
#  'output_229.html',
#  'output_230.html',
#  'output_231.html',
#  'output_232.html',
#  'output_233.html',
#  'output_234.html',
#  'output_235.html',
#  'output_236.html',
#  'output_237.html',
#  'output_238.html',
#  'output_239.html',
#  'output_240.html',
#  'output_241.html',
#  'output_242.html',
#  'output_243.html',
#  'output_244.html',
#  'output_245.html',
#  'output_246.html',
#  'output_247.html',
#  'output_248.html',
#  'output_249.html',
#  'output_250.html',
#  'output_251.html',
#  'output_252.html',
#  'output_253.html',
#  'output_254.html',
#  'output_255.html',
#  'output_256.html',
#  'output_257.html',
#  'output_258.html',
#  'output_259.html',
#  'output_260.html',
#  'output_261.html',
#  'output_262.html',
#  'output_263.html',
#  'output_264.html',
#  'output_265.html',
#  'output_266.html',
#  'output_267.html',
#  'output_268.html',
#  'output_269.html',
#  'output_270.html',
#  'output_271.html',
#  'output_272.html',
#  'output_273.html',
#  'output_274.html',
#  'output_275.html',
#  'output_276.html',
#  'output_277.html',
#  'output_278.html',
#  'output_279.html',
#  'output_280.html',
#  'output_281.html',
#  'output_282.html',
#  'output_283.html',
#  'output_284.html',
#  'output_285.html',
#  'output_286.html',
#  'output_287.html',
#  'output_288.html',
#  'output_289.html',
#  'output_290.html',
#  'output_291.html',
#  'output_292.html',
#  'output_293.html',
#  'output_294.html',
#  'output_295.html',
#  'output_296.html',
#  'output_297.html',
#  'output_298.html',
#  'output_299.html',
#  'output_300.html',
#  'output_301.html',
#  'output_302.html',
#  'output_303.html',
#  'output_304.html',
#  'output_305.html',
#  'output_306.html',
#  'output_307.html',
#  'output_308.html',
#  'output_309.html',
#  'output_310.html',
#  'output_311.html',
#  'output_312.html',
#  'output_313.html',
#  'output_314.html',
#  'output_315.html',
#  'output_316.html',
#  'output_317.html',
#  'output_318.html',
#  'output_319.html',
#  'output_320.html',
#  'output_321.html',
#  'output_322.html',
#  'output_323.html',
#  'output_324.html',
#  'output_325.html',
#  'output_326.html',
#  'output_327.html',
#  'output_328.html',
#  'output_329.html',
#  'output_330.html',
#  'output_331.html',
#  'output_332.html',
#  'output_333.html',
#  'output_334.html',
#  'output_335.html',
#  'output_336.html',
#  'output_337.html',
#  'output_338.html',
#  'output_339.html',
#  'output_340.html',
#  'output_341.html',
#  'output_342.html',
#  'output_343.html',
#  'output_344.html',
#  'output_345.html',
#  'output_346.html',
#  'output_347.html',
#  'output_348.html',
#  'output_349.html',
#  'output_350.html',
#  'output_351.html',
#  'output_352.html',
#  'output_353.html',
#  'output_354.html',
#  'output_355.html',
#  'output_356.html',
#  'output_357.html',
#  'output_358.html',
#  'output_359.html',
#  'output_360.html',
#  'output_361.html',
#  'output_362.html',
#  'output_363.html',
#  'output_364.html',
#  'output_365.html',
#  'output_366.html',
#  'output_367.html',
#  'output_368.html',
#  'output_369.html',
#  'output_370.html',
#  'output_371.html',
#  'output_372.html',
#  'output_373.html',
#  'output_374.html',
#  'output_375.html',
#  'output_376.html',
#  'output_377.html',
#  'output_378.html',
#  'output_379.html',
#  'output_380.html',
#  'output_381.html',
#  'output_382.html',
#  'output_383.html',
#  'output_384.html',
#  'output_385.html',
#  'output_386.html',
#  'output_387.html',
#  'output_388.html',
#  'output_389.html',
#  'output_390.html',
#  'output_391.html',
#  'output_392.html',
#  'output_393.html',
#  'output_394.html',
#  'output_395.html',
#  'output_396.html',
#  'output_397.html',
#  'output_398.html',
#  'output_399.html',
#  'output_400.html',
#  'output_401.html',
#  'output_402.html',
#  'output_403.html',
#  'output_404.html',
#  'output_405.html',
#  'output_406.html',
#  'output_407.html',
#  'output_408.html',
#  'output_409.html',
#  'output_410.html',
#  'output_411.html',
#  'output_412.html',
#  'output_413.html',
#  'output_414.html',
#  'output_415.html',
#  'output_416.html',
#  'output_417.html',
#  'output_418.html',
#  'output_419.html',
#  'output_420.html',
#  'output_421.html',
#  'output_422.html',
#  'output_423.html',
#  'output_424.html',
#  'output_425.html',
#  'output_426.html',
#  'output_427.html',
#  'output_428.html',
#  'output_429.html',
#  'output_430.html',
#  'output_431.html',
#  'output_432.html',
#  'output_433.html',
#  'output_434.html',
#  'output_435.html',
#  'output_436.html',
#  'output_437.html',
#  'output_438.html',
#  'output_439.html',
#  'output_440.html',
#  'output_441.html',
#  'output_442.html',
#  'output_443.html',
#  'output_444.html',
#  'output_445.html',
#  'output_446.html',
#  'output_447.html',
#  'output_448.html',
#  'output_449.html',
#  'output_450.html',
#  'output_451.html',
#  'output_452.html',
#  'output_453.html',
#  'output_454.html',
#  'output_455.html',
#  'output_456.html',
#  'output_457.html',
#  'output_458.html',
#  'output_459.html',
#  'output_460.html',
#  'output_461.html',
#  'output_462.html',
#  'output_463.html',
#  'output_464.html',
#  'output_465.html',
#  'output_466.html',
#  'output_467.html',
#  'output_468.html',
#  'output_469.html',
#  'output_470.html',
#  'output_471.html',
#  'output_472.html',
#  'output_473.html',
#  'output_474.html',
#  'output_475.html',
#  'output_476.html',
#  'output_477.html',
#  'output_478.html',
#  'output_479.html',
#  'output_480.html',
#  'output_481.html',
#  'output_482.html',
#  'output_483.html',
#  'output_484.html',
#  'output_485.html',
#  'output_486.html',
#  'output_487.html',
#  'output_488.html',
#  'output_489.html',
#  'output_490.html',
#  'output_491.html',
#  'output_492.html',
#  'output_493.html',
#  'output_494.html',
#  'output_495.html',
#  'output_496.html',
#  'output_497.html',
#  'output_498.html',
#  'output_499.html',
#  'output_500.html',
#  'output_501.html',
#  'output_502.html',
#  'output_503.html',
#  'output_504.html',
#  'output_505.html',
#  'output_506.html',
#  'output_507.html',
#  'output_508.html',
#  'output_509.html',
#  'output_510.html',
#  'output_511.html',
#  'output_512.html',
#  'output_513.html',
#  'output_514.html',
#  'output_515.html',
#  'output_516.html',
#  'output_517.html',
#  'output_518.html',
#  'output_519.html',
#  'output_520.html',
#  'output_521.html',
#  'output_522.html',
#  'output_523.html',
#  'output_524.html',
#  'output_525.html',
#  'output_526.html',
#  'output_527.html',
#  'output_528.html',
#  'output_529.html',
#  'output_530.html',
#  'output_531.html',
#  'output_532.html',
#  'output_533.html',
#  'output_534.html',
#  'output_535.html',
#  'output_536.html',
#  'output_537.html']

# %%
id_s = []
for d in dirs:
    file= codecs.open("html/"+ d, 'r',  encoding="utf8")
    parsed = json.loads(file.read())
    print(d + " DONE!", end = "\r")
    
    for i in range(100):
        try: 
            id_s.append(parsed['kitties'][i]['id'])
        except:
            print("\n" + str(d))
# Out:
# output_537.html DONE!
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html
#
# output_537.html

# %%
len(id_s)
# Out:
# 53646

# %%
# data = pd.DataFrame(data = id_s, columns = ["ID"])

# %%
data.head(10)
# Out:
#         ID
# 0   911864
# 1  1492158
# 2  1467026
# 3  1607601
# 4  1409715
# 5  1379635
# 6  1240154
# 7  1477703
# 8  1546611
# 9  1505927

# %%
# Random
data['generation'] = ''
data['color'] = ''
data['is_fancy'] = ''
data['is_exclusive'] = ''
data['fancy_type'] = ''
data['is_prestige'] = ''
data['prestige_type'] = ''
data['prestige_ranking'] = ''
data['fancy_ranking'] = ''
data['prestige_time_limit'] = ''

# Enhanced cattributes
data['enhanced_cattributes_eyes'] = '' 
data['enhanced_cattributes_pattern'] = '' 
data['enhanced_cattributes_body'] = '' 
data['enhanced_cattributes_mouth'] = '' 
data['enhanced_cattributes_colorprimary'] = '' 
data['enhanced_cattributes_colorsecondary'] = '' 
data['enhanced_cattributes_colortertiary'] = '' 
data['enhanced_cattributes_coloreyes'] = '' 

# Status
data['status_cooldown_index'] = ''
data['status_is_ready'] = ''
data['status_is_gestating'] = ''

# Purrs
data['purrs_count'] = ''
data['purrs_is_purred'] = ''

# watchlist
data['watchlist_count'] = ''
data['watchlist_is_watchlisted'] = ''

# %%
data.to_csv("Latest.csv", index = False)

# %% [markdown]
# ## NEED TO FIGURE THIS OUT!

# %%
for k in range(len(data)):
    
    file= codecs.open("html/output_" + dirs[k] + ".html", 'r',  encoding="utf8")
    parsed = json.loads(file.read())

    
    
#     # Random
#     data.iloc[k, 3] = parsed['generation']        
#     data.iloc[k, 4] = parsed['color']
#     data.iloc[k, 5] = parsed['is_fancy']
#     data.iloc[k, 6] = parsed['is_exclusive']
#     data.iloc[k, 7] = parsed['fancy_type']
#     data.iloc[k, 8] = parsed['is_prestige']
#     data.iloc[k, 9] = parsed['prestige_type']
#     data.iloc[k, 10] = parsed['prestige_ranking']
#     data.iloc[k, 11] = parsed['fancy_ranking']
#     data.iloc[k, 12] = parsed['prestige_time_limit']

#     # Enhanced cattributes
#     if parsed['enhanced_cattributes'] != []:
#         data.iloc[k, 13] = parsed['enhanced_cattributes'][0]['description']
#         data.iloc[k, 14] = parsed['enhanced_cattributes'][1]['description']
#         data.iloc[k, 15] = parsed['enhanced_cattributes'][2]['description']
#         data.iloc[k, 16] = parsed['enhanced_cattributes'][3]['description']
#         data.iloc[k, 17] = parsed['enhanced_cattributes'][4]['description']
#         data.iloc[k, 18] = parsed['enhanced_cattributes'][5]['description']
#         data.iloc[k, 19] = parsed['enhanced_cattributes'][6]['description'] 
#         data.iloc[k, 20] = parsed['enhanced_cattributes'][7]['description']

#     # Status
#     data.iloc[k, 21] = parsed['status']['cooldown_index']
#     data.iloc[k, 22] = parsed['status']['is_ready']
#     data.iloc[k, 23] = parsed['status']['is_gestating']

#     # Purrs
#     data.iloc[k, 24] = parsed['purrs']['count']
#     data.iloc[k, 25] = parsed['purrs']['is_purred']

#     # watchlist
#     data.iloc[k, 26] = parsed['watchlist']['count']
#     data.iloc[k, 27] = parsed['watchlist']['is_watchlisted']


#     print(f"we at: {k} out of 53646. Giving us percent complete of {round(100*k/53646, 5)}%   ", end = "\r")

#     if k % 100 == 0:
#         data.to_csv("Latest.csv.csv", index = False)
