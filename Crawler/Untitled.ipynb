# %%
import pandas as pd

# %%
pd.read_csv('Latest_kitties_2019-07-09T08-59-08.csv').tail(10)
# Out:
#        time       ID  USD  generation        color  is_fancy  is_exclusive  \
# 53666   NaN  1491649  1.0          13        olive      True         False
# 53667   NaN   625205  1.0          16  thundergrey     False         False
# 53668   NaN   449426  1.0           0         gold     False         False
# 53669   NaN  1227139  1.0           8     parakeet     False         False
# 53670   NaN   625180  1.0          10  thundergrey     False         False
# 53671   NaN   793184  1.0           2   strawberry      True         False
# 53672   NaN  1000001  1.0           2        olive     False         False
# 53673   NaN   830610  1.0           0       dahlia     False         False
# 53674   NaN  1602202  1.0          12   strawberry     False         False
# 53675   NaN  1257987  1.0          10     chestnut     False         False
#
#       fancy_type  is_prestige prestige_type  ...  \
# 53666     Clover        False           NaN  ...
# ...
