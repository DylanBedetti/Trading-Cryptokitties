# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split

pd.set_option("max_columns", 30)

# %%
data = pd.read_csv("../Crawler/Latest.csv")
# data['time'] = pd.to_timedelta(pd.to_datetime(pd.read_csv("../Data/train_complete.csv")['time'].apply(lambda x: x[:10])), unit = 'seconds').astype('timedelta64[D]')[0]
data['time'] = 18074.0
data['prestige_time_limit'] = data['prestige_time_limit'].apply(lambda x: np.nan if pd.isnull(x) else x[:10])
data['prestige_time_limit'] = pd.to_timedelta(pd.to_datetime(data['prestige_time_limit']), unit = 'seconds').astype('timedelta64[D]')

trends = pd.read_csv("../Data/trends.csv")

ETH = pd.read_csv("../Data/ETH_price.csv")
ETH = ETH[["date", "close"]]

data['trends'] = trends['cryptokitties']
data['close'] = ETH['close']

data['USD'] = data['USD'] * ETH['close'][0]

data = data.fillna('0')

data.head()
# Out:
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#   """
#       time       ID      USD  generation        color  is_fancy  is_exclusive  \
# 0  18074.0   911864  25.6048         4.0      sizzurp      True         False
# 1  18074.0  1492158  25.6048         8.0         gold     False         False
# 2  18074.0  1467026  25.6048        15.0  thundergrey     False         False
# 3  18074.0  1607601  25.6048        15.0     chestnut     False         False
# 4  18074.0  1409715  25.6048         3.0       dahlia     False         False
#
#   fancy_type  is_prestige prestige_type prestige_ranking fancy_ranking  \
# 0    Purrity        False             0                0           259
# 1          0        False             0                0             0
# 2          0         True       inaband              768             0
# 3          0        False             0                0             0
# 4          0        False             0                0             0
#
#   prestige_time_limit enhanced_cattributes_eyes enhanced_cattributes_pattern  \
# 0                   0                         0                            0
# 1                   0                     pouty                         camo
# 2               17981                  munchkin                       simple
# 3                   0               thicccbrowz                 whixtensions
# 4                   0                   selkirk                       simple
#
#   enhanced_cattributes_body enhanced_cattributes_mouth  \
# 0                         0                          0
# 1                      asif                 koladiviya
# 2                totesbasic                  soserious
# 3                   ragdoll                       amur
# 4                    struck                  rorschach
#
#   enhanced_cattributes_colorprimary enhanced_cattributes_colorsecondary  \
# 0                                 0                                   0
# 1                          brownies                               lilac
# 2                       bananacream                              coffee
# 3                          brownies                             skyblue
# 4                        cinderella                             apricot
#
#   enhanced_cattributes_colortertiary enhanced_cattributes_coloreyes  \
# 0                                  0                              0
# 1                       emeraldgreen                           gold
# 2                           atlantis                    thundergrey
# 3                                icy                       chestnut
# 4                              shale                         dahlia
#
#    status_cooldown_index  status_is_ready  status_is_gestating  purrs_count  \
# 0                   12.0             True                False          1.0
# 1                    5.0             True                False          1.0
# 2                   11.0             True                False          1.0
# 3                   10.0             True                False          0.0
# 4                    1.0             True                False          1.0
#
#    purrs_is_purred  watchlist_count  watchlist_is_watchlisted    trends  \
# 0            False              0.0                     False  0.485359
# 1            False              0.0                     False  0.342606
# 2            False              0.0                     False  0.513909
# 3            False              0.0                     False  0.342606
# 4            False              0.0                     False   1.17057
#
#     close
# 0  320.06
# 1  311.23
# 2  294.27
# 3  336.75
# 4  318.13

# %%
from collections import defaultdict
d = defaultdict(LabelEncoder)

# %%
dirs = [x.split(".")[0] for x in os.listdir("Saved_encoder/")]
dirs
# Out:
# ['color',
#  'enhanced_cattributes_body',
#  'enhanced_cattributes_coloreyes',
#  'enhanced_cattributes_colorprimary',
#  'enhanced_cattributes_colorsecondary',
#  'enhanced_cattributes_colortertiary',
#  'enhanced_cattributes_eyes',
#  'enhanced_cattributes_mouth',
#  'enhanced_cattributes_pattern',
#  'fancy_type',
#  'prestige_type']

# %% [markdown]
# ## IMPORTING LABLEENCODERS

# %%
for e in dirs:
    d[e].classes_ = np.load(f'Saved_encoder/{e}.npy', allow_pickle = True)

# %%
cols = ['color', 'fancy_type', 'prestige_type', 'enhanced_cattributes_eyes', 'enhanced_cattributes_pattern', 'enhanced_cattributes_body', 'enhanced_cattributes_mouth', 'enhanced_cattributes_colorprimary', 'enhanced_cattributes_colorsecondary', 'enhanced_cattributes_colortertiary', 'enhanced_cattributes_coloreyes']

# %% [markdown]
# ## ACCOUNTING FOR UNSEEN VARIABLES!!

# %%
import bisect

for c in cols:
    data[c] = data[c].map(lambda s: 'other' if s not in d[c].classes_ else s)
    
    le_classes = d[c].classes_.tolist()
    bisect.insort_left(le_classes, 'other')
    d[c].classes_ = le_classes

# %%
data[cols] = data[cols].apply(lambda x: d[x.name].transform(x))

# %%
data.head(10)
# Out:
#       time       ID      USD  generation  color  is_fancy  is_exclusive  \
# 0  18074.0   911864  25.6048         4.0     25      True         False
# 1  18074.0  1492158  25.6048         8.0     12     False         False
# 2  18074.0  1467026  25.6048        15.0     27     False         False
# 3  18074.0  1607601  25.6048        15.0      4     False         False
# 4  18074.0  1409715  25.6048         3.0      7     False         False
# 5  18074.0  1379635  25.6048        14.0      7     False         False
# 6  18074.0  1240154  25.6048         6.0     15      True         False
# 7  18074.0  1477703  25.6048        15.0     24      True         False
# 8  18074.0  1546611  25.6048         8.0     18     False         False
# 9  18074.0  1505927  25.6048         2.0      5     False         False
#
#    fancy_type  is_prestige  prestige_type prestige_ranking fancy_ranking  \
# 0          52        False              0                0           259
# 1           0        False              0                0             0
# 2           0         True             15              768             0
# 3           0        False              0                0             0
# 4           0        False              0                0             0
# 5           0        False              0                0             0
# 6          18        False              0                0          2456
# 7          11        False              0                0           844
# 8           0         True             16              353             0
# 9           0        False              0                0             0
#
#   prestige_time_limit  enhanced_cattributes_eyes  \
# 0                   0                          0
# 1                   0                         96
# 2               17981                         83
# 3                   0                        129
# 4                   0                        112
# 5                   0                        136
# 6                   0                          0
# 7                   0                          0
# 8               18026                         88
# 9                   0                         98
#
#    enhanced_cattributes_pattern  enhanced_cattributes_body  \
# 0                             0                          0
# 1                            25                          8
# 2                           149                        185
# 3                           182                        139
# 4                           149                        170
# 5                           182                        139
# 6                             0                          0
# 7                             0                          0
# 8                           164                        185
# 9                            64                        155
#
#    enhanced_cattributes_mouth  enhanced_cattributes_colorprimary  \
# 0                           0                                  0
# 1                         104                                 25
# 2                         174                                 15
# 3                           5                                 25
# 4                         153                                 37
# 5                         173                                134
# 6                           0                                  0
# 7                           0                                  0
# 8                         125                                165
# 9                           4                                 84
#
#    enhanced_cattributes_colorsecondary  enhanced_cattributes_colortertiary  \
# 0                                    0                                   0
# 1                                   99                                  43
# 2                                   33                                   5
# 3                                  155                                  65
# 4                                    4                                 121
# 5                                  161                                  99
# 6                                    0                                   0
# 7                                    0                                   0
# 8                                  101                                  35
# 9                                   97                                 105
#
#    enhanced_cattributes_coloreyes  status_cooldown_index  status_is_ready  \
# 0                               0                   12.0             True
# 1                              55                    5.0             True
# 2                             134                   11.0             True
# 3                              25                   10.0             True
# 4                              36                    1.0             True
# 5                              36                    7.0             True
# 6                               0                    5.0             True
# 7                               0                    8.0             True
# 8                             126                    4.0             True
# 9                              30                    1.0             True
#
#    status_is_gestating  purrs_count  purrs_is_purred  watchlist_count  \
# 0                False          1.0            False              0.0
# 1                False          1.0            False              0.0
# 2                False          1.0            False              0.0
# 3                False          0.0            False              0.0
# 4                False          1.0            False              0.0
# 5                False          1.0            False              0.0
# 6                False          1.0            False              0.0
# 7                False          1.0            False              0.0
# 8                False          1.0            False              0.0
# 9                False          1.0            False              0.0
#
#    watchlist_is_watchlisted    trends   close
# 0                     False  0.485359  320.06
# 1                     False  0.342606  311.23
# 2                     False  0.513909  294.27
# 3                     False  0.342606  336.75
# 4                     False   1.17057  318.13
# 5                     False  0.970717  310.42
# 6                     False  0.713763  307.83
# 7                     False   1.37042  309.38
# 8                     False  0.342606  294.91
# 9                     False  0.827965   271.7

# %%
X = data.drop('USD', axis = 1)
X.head(5)
# Out:
#       time       ID  generation  color  is_fancy  is_exclusive  fancy_type  \
# 0  18074.0   911864         4.0     25      True         False          52
# 1  18074.0  1492158         8.0     12     False         False           0
# 2  18074.0  1467026        15.0     27     False         False           0
# 3  18074.0  1607601        15.0      4     False         False           0
# 4  18074.0  1409715         3.0      7     False         False           0
#
#    is_prestige  prestige_type prestige_ranking fancy_ranking  \
# 0        False              0                0           259
# 1        False              0                0             0
# 2         True             15              768             0
# 3        False              0                0             0
# 4        False              0                0             0
#
#   prestige_time_limit  enhanced_cattributes_eyes  \
# 0                   0                          0
# 1                   0                         96
# 2               17981                         83
# 3                   0                        129
# 4                   0                        112
#
#    enhanced_cattributes_pattern  enhanced_cattributes_body  \
# 0                             0                          0
# 1                            25                          8
# 2                           149                        185
# 3                           182                        139
# 4                           149                        170
#
#    enhanced_cattributes_mouth  enhanced_cattributes_colorprimary  \
# 0                           0                                  0
# 1                         104                                 25
# 2                         174                                 15
# 3                           5                                 25
# 4                         153                                 37
#
#    enhanced_cattributes_colorsecondary  enhanced_cattributes_colortertiary  \
# 0                                    0                                   0
# 1                                   99                                  43
# 2                                   33                                   5
# 3                                  155                                  65
# 4                                    4                                 121
#
#    enhanced_cattributes_coloreyes  status_cooldown_index  status_is_ready  \
# 0                               0                   12.0             True
# 1                              55                    5.0             True
# 2                             134                   11.0             True
# 3                              25                   10.0             True
# 4                              36                    1.0             True
#
#    status_is_gestating  purrs_count  purrs_is_purred  watchlist_count  \
# 0                False          1.0            False              0.0
# 1                False          1.0            False              0.0
# 2                False          1.0            False              0.0
# 3                False          0.0            False              0.0
# 4                False          1.0            False              0.0
#
#    watchlist_is_watchlisted    trends   close
# 0                     False  0.485359  320.06
# 1                     False  0.342606  311.23
# 2                     False  0.513909  294.27
# 3                     False  0.342606  336.75
# 4                     False   1.17057  318.13

# %%
model_name = os.listdir("Saved_models/")[-1]

# %%
import pickle
loaded_model = pickle.load(open(f"Saved_models/{model_name}", 'rb'))
res = loaded_model.predict(X)
print(res)
# Out:
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:    0.0s
# [ 75.2756       2.33526667  21.3223     ... 133.3459875  402.3748
#   17.21150833]
# [Parallel(n_jobs=6)]: Done 100 out of 100 | elapsed:    0.2s finished

# %%
results = dict()

# %%
results["predictions"] =  res
results["sale_price"] = data['USD']
results["ID"] = data['ID']

# %%
k = 0
best = []
print("")
for i in range(len(res)):
    if results["predictions"][i] > results["sale_price"][i]*14:
        print(round(results["predictions"][i],2), round(results["sale_price"][i],2), results["ID"][i])
        k+=1
        best.append([round(results["predictions"][i],2), round(results["sale_price"][i],2), results["ID"][i]])
print(k)
# Out:
# 381.61 25.6 560270
# 378.29 25.6 500361
# 368.35 25.6 467130
# 358.96 25.6 468434
# 407.85 25.6 467737
# 414.56 26.76 845684
# 6

# %%
from IPython.core.display import display, HTML


display(HTML(' <a href="google.com"><h5>Hello, world!</h5>'))
# Out:
#  <a href="google.com"><h5>Hello, world!</h5>

# %%
best
# Out:
# [[381.61, 25.6, 560270],
#  [378.29, 25.6, 500361],
#  [368.35, 25.6, 467130],
#  [358.96, 25.6, 468434],
#  [407.85, 25.6, 467737],
#  [414.56, 26.76, 845684]]
