# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("max_columns", 30)
# %matplotlib inline
# %matplotlib notebook

# %%
data = pd.read_csv("../Model/Saved_predictions/predictions_2019-07-08T20-52-52.csv")
data.head()
# Out:
#       date       ID     USD  generation        color  is_fancy  is_exclusive  \
# 0  18084.0  1532879  23.004           9  forgetmenot     False         False
# 1  18084.0  1460942  23.004          17     sapphire     False         False
# 2  18084.0  1549546  23.004           5    mintgreen     False         False
# 3  18084.0  1513584  23.004           4       dahlia     False         False
# 4  18084.0  1132878  23.004           2     sapphire     False         False
#
#   fancy_type  is_prestige prestige_type  prestige_ranking  fancy_ranking  \
# 0        NaN         True       timbers             141.0            NaN
# 1        NaN        False           NaN               NaN            NaN
# 2        NaN        False           NaN               NaN            NaN
# 3        NaN        False           NaN               NaN            NaN
# 4        NaN        False           NaN               NaN            NaN
#
# ...

# %%
data['USD'].plot.hist(bins = 40)

# %%
data['predictions'].plot.hist(bins = 40)

# %%
d = pd.read_csv("../Data/train_complete.csv")

d.head()
# Out:
#                        time       ID    USD  generation      color  is_fancy  \
# 0  2019-07-07T08:02:14.000Z  1636098   3.13         9.0     dahlia     False
# 1  2019-07-07T07:56:13.000Z   882455  22.04         3.0       cyan     False
# 2  2019-07-07T07:53:11.000Z  1111595   3.96        11.0   sapphire     False
# 3  2019-07-07T07:51:01.000Z  1630571   2.54         9.0  mintgreen     False
# 4  2019-07-07T07:48:58.000Z  1553187   0.29         8.0   parakeet     False
#
#    is_exclusive fancy_type  is_prestige prestige_type  prestige_ranking  \
# 0         False        NaN        False           NaN               NaN
# 1         False        NaN        False           NaN               NaN
# 2         False        NaN         True   duckduckcat             198.0
# 3         False        NaN        False           NaN               NaN
# 4         False        NaN        False           NaN               NaN
#
#    fancy_ranking   prestige_time_limit enhanced_cattributes_eyes  \
# ...

# %%
# %matplotlib notebook
f = plt.figure(figsize=(5,5))
d['USD'].plot.hist(bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
(d["USD"] > 1000).sum()
# Out:
# 29

# %%
d['ID'][d["USD"] > 2000]
# Out:
# 936       995745
# 1686         271
# 2319      782398
# 2630        1825
# 4697     1137670
# 15623        108
# 17340         75
# 45845         80
# 52458    1495791
# 53610        150
# 54045        123
# 64753    1382014
# 64754    1394654
# 64817    1399502
# 64819    1407252
# 66749         86
# Name: ID, dtype: int64

# %%
d[['ID','fancy_type','USD', 'fancy_ranking']][(d["fancy_type"] == "Dukecat")].sort_values('USD', ascending=False)[:30]
# Out:
#              ID fancy_type     USD  fancy_ranking
# 73317   1113787    Dukecat  134.34          514.0
# 67219   1143823    Dukecat   70.10         1365.0
# 56771   1105253    Dukecat   49.45           35.0
# 67833   1105202    Dukecat   28.36           31.0
# 48356   1104858    Dukecat   26.41           22.0
# 68442   1105270    Dukecat   24.04           36.0
# 4706    1118224    Dukecat   17.69          578.0
# 47524   1115667    Dukecat   15.46          541.0
# 71637   1119942    Dukecat   11.46          622.0
# 71795   1120214    Dukecat   10.69          630.0
# 3468    1109780    Dukecat   10.06          414.0
# 10029   1142773    Dukecat   10.04         1281.0
# 74976   1126712    Dukecat    9.79          718.0
# 54013   1141986    Dukecat    9.54         1213.0
# 42289   1142299    Dukecat    9.17         1247.0
# 46656   1123285    Dukecat    8.97          658.0
# 34976   1117672    Dukecat    8.68          572.0
# 106015  1139887    Dukecat    8.46         1119.0
# ...

# %%
data[['ID','fancy_type', 'USD', 'predictions', 'fancy_ranking']][data["predictions"] > 400]
# Out:
#             ID   fancy_type         USD  predictions  fancy_ranking
# 48664   728588   Flutterbee  215.662500     458.6760          191.0
# 49190   549844  YuriCatsuki  246.928010     514.4881          209.0
# 49312   756906      DocPurr  258.795000     533.2163          146.0
# 50129  1129992       LilBUB  264.546000     495.2068            NaN
# 50141   634057        Berry  265.309946     469.6213          155.0
# 50236  1640008     Catamari  284.674500     423.6694            5.0
# 51613   729211   Flutterbee  287.550000     483.0317          219.0
# 52212   756173      DocPurr  287.550000     465.7488           87.0
# 52793   756173      DocPurr  287.550000     465.7488           87.0
# 52871   572088        Tabby  287.550000     413.9139          245.0

# %%
data['ratio'] = data['predictions']/data['USD']

# %%
data.sort_values('ratio', ascending=False)[:20]
# Out:
#           date       ID        USD  generation         color  is_fancy  \
# 14930  18084.0   432186  28.755000           1         topaz     False
# 5463   18084.0   551757  25.879500           7          gold     False
# 1324   18084.0    28461  23.004000           6       sizzurp     False
# 7122   18084.0   587147  27.317250           2  coralsunrise     False
# 5458   18084.0   600650  25.879500           2      chestnut     False
# 9852   18084.0  1398950  28.755000           4   thundergrey      True
# 272    18084.0   542081  23.004000           4    strawberry     False
# 24454  18084.0   519681  43.132500           2         topaz     False
# 7899   18084.0   668385  27.317250           2     mintgreen     False
# 705    18084.0   531902  23.004000           3    strawberry     False
# 12560  18084.0   591514  28.755000           6      chestnut      True
# 4890   18084.0   589888  25.304400           5      sapphire     False
# ...

# %%
data[data['is_prestige']==True]
# Out:
#           date       ID      USD  generation            color  is_fancy  \
# 0      18084.0  1532879   23.004           9      forgetmenot     False
# 9      18084.0  1313291   23.004           6      thundergrey     False
# 12     18084.0  1310991   23.004           9        bubblegum     False
# 14     18084.0  1530495   23.004           8             cyan     False
# 19     18084.0  1308526   23.004           4         chestnut     False
# 44     18084.0  1296012   23.004          10            olive     False
# 56     18084.0  1038115   23.004           6           dahlia     False
# 57     18084.0  1037371   23.004           6      thundergrey     False
# 58     18084.0  1037170   23.004           6           dahlia     False
# 59     18084.0  1037096   23.004           6      thundergrey     False
# 65     18084.0  1042953   23.004          24        bubblegum     False
# 66     18084.0  1054294   23.004          22        mintgreen     False
# ...
