# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("max_columns", 40)
# %matplotlib inline
# %matplotlib notebook

# %%
data = pd.read_csv("../Model/Saved_predictions/predictions_2019-07-09T20-40-31.csv")
data['ratio'] = data['predictions']/data['USD']
data.head()
# Out:
#       date       ID    USD  generation         color  is_fancy  is_exclusive  \
# 0  18086.0  1641928  2.506          19     mintgreen     False         False
# 1  18086.0   726105  2.506           1  coralsunrise     False         False
# 2  18086.0   715085  2.506           1  coralsunrise     False         False
# 3  18086.0  1628244  2.506           3   thundergrey     False         False
# 4  18086.0  1628247  2.506           1         olive     False         False
#
#   fancy_type  is_prestige prestige_type  prestige_ranking  fancy_ranking  \
# 0        NaN        False           NaN               NaN            NaN
# 1        NaN        False           NaN               NaN            NaN
# 2        NaN        False           NaN               NaN            NaN
# 3        NaN        False           NaN               NaN            NaN
# 4        NaN        False           NaN               NaN            NaN
#
# ...

# %%
# data['USD'].plot.hist(bins = 100)

# %%
# %matplotlib notebook
# data['predictions'].plot.hist(bins = 100)

# %%
d = pd.read_csv("../Data/train_complete.csv")

d.head()
# Out:
#                        time       ID   USD  generation      color  is_fancy  \
# 0  2019-07-09T11:32:12.000Z  1433595  0.48         7.0       cyan     False
# 1  2019-07-09T11:31:27.000Z  1164094  0.49         2.0    sizzurp     False
# 2  2019-07-09T11:31:27.000Z  1428104  0.48         4.0  mintgreen     False
# 3  2019-07-09T11:31:06.000Z  1172808  0.49         2.0      olive     False
# 4  2019-07-09T11:30:57.000Z  1170634  0.50         2.0      olive     False
#
#    is_exclusive fancy_type  is_prestige prestige_type  prestige_ranking  \
# 0         False        NaN        False           NaN               NaN
# 1         False        NaN        False           NaN               NaN
# 2         False        NaN        False           NaN               NaN
# 3         False        NaN        False           NaN               NaN
# 4         False        NaN        False           NaN               NaN
#
#    fancy_ranking prestige_time_limit enhanced_cattributes_eyes  \
# ...

# %%
# %matplotlib notebook
# f = plt.figure(figsize=(5,5))
# d['USD'].plot.hist(bins = 100)

# %%
# (d["USD"] > 1000).sum()

# %%
d[['ID','fancy_type','USD', 'fancy_ranking']][(d["fancy_type"] == "SheilaPurren")].sort_values('USD', ascending=False)[:20]
# Out:
#              ID    fancy_type     USD  fancy_ranking
# 72728   1091283  SheilaPurren  401.33         1971.0
# 49508   1070307  SheilaPurren   25.67           30.0
# 35566   1070522  SheilaPurren   17.67           41.0
# 97128   1084699  SheilaPurren   10.78         1111.0
# 8707    1083251  SheilaPurren   10.12          875.0
# 30292   1085311  SheilaPurren    9.09         1182.0
# 11762   1089263  SheilaPurren    8.38         1600.0
# 10807   1089447  SheilaPurren    7.98         1647.0
# 19102   1090940  SheilaPurren    7.97         1923.0
# 5967    1082818  SheilaPurren    7.72          822.0
# 79750   1083611  SheilaPurren    7.63          942.0
# 7883    1075318  SheilaPurren    7.48          215.0
# 86513   1090854  SheilaPurren    7.22         1916.0
# 49617   1075152  SheilaPurren    6.93          205.0
# 73892   1090913  SheilaPurren    6.89         1920.0
# 49819   1082323  SheilaPurren    6.49          757.0
# 106954  1090989  SheilaPurren    6.26         1931.0
# ...

# %%
data[['ID','fancy_type', 'USD', 'predictions', 'fancy_ranking']][data["predictions"] > 100]
# Out:
#             ID fancy_type       USD  predictions  fancy_ranking
# 165    1610472        NaN  2.506000   189.715277            NaN
# 4916   1610443        NaN  2.520361   184.729577            NaN
# 26841  1610450        NaN  3.134451   183.467577            NaN
# 45648  1479282        NaN  5.697401   629.814200            NaN

# %%
data.sort_values('ratio', ascending=False)[:20]
# Out:
#           date       ID       USD  generation        color  is_fancy  \
# 45648  18086.0  1479282  5.697401          17         gold     False
# 165    18086.0  1610472  2.506000           8        topaz     False
# 4916   18086.0  1610443  2.520361          15        topaz     False
# 26841  18086.0  1610450  3.134451          12        topaz     False
# 2857   18086.0   350604  2.506000           3      sizzurp     False
# 2109   18086.0   668340  2.506000           7  thundergrey     False
# 22902  18086.0   322678  3.132500           8      sizzurp     False
# 4964   18086.0  1448392  2.537325           1  thundergrey     False
# 6858   18086.0   680280  2.819250           2    mintgreen     False
# 9701   18086.0   274732  2.819250           6        topaz     False
# 19577  18086.0   626438  3.132500           3   strawberry     False
# 4963   18086.0  1482597  2.537325           1       dahlia     False
# 1711   18086.0   861961  2.506000          11   strawberry     False
# ...

# %%
data[data['fancy_type'] == "Purrspero"][:10]
# Out:
#           date       ID       USD  generation       color  is_fancy  \
# 42750  18086.0  1024705  5.325250          13  strawberry      True
# 47412  18086.0   938419  6.005987          13        cyan      True
#
#        is_exclusive fancy_type  is_prestige prestige_type  prestige_ranking  \
# 42750         False  Purrspero        False           NaN               NaN
# 47412         False  Purrspero        False           NaN               NaN
#
#        fancy_ranking  prestige_time_limit enhanced_cattributes_eyes  \
# 42750         4376.0                  NaN                       NaN
# 47412         1539.0                  NaN                       NaN
#
#       enhanced_cattributes_pattern enhanced_cattributes_body  \
# 42750                          NaN                       NaN
# 47412                          NaN                       NaN
#
#       enhanced_cattributes_mouth enhanced_cattributes_colorprimary  \
# ...

# %%
data['fancy_type'].value_counts()
# Out:
# Furbeard              77
# Curdlin               68
# Page                  42
# Pawrula               30
# Pizzazz               26
# TallyThePurrocious    14
# Al                    12
# DuCat                 10
# Swish                  9
# Glitter                6
# ChatPlongeur           4
# Clover                 4
# Dreggo                 3
# SheilaPurren           2
# Purrspero              2
# Purrity                1
# GeneDough              1
# Name: fancy_type, dtype: int64

# %%
pd.isnull(data['fancy_type'][0])
# Out:
# True

# %%
data[~pd.isnull(data['fancy_type'])].sort_values('ratio', ascending=False)[:30]
# Out:
#           date       ID       USD  generation         color  is_fancy  \
# 47338  18086.0  1086158  6.265000          14   thundergrey      True
# 43844  18086.0  1082778  5.574819          11        dahlia      True
# 46968  18086.0  1554535  5.957345           5      sapphire      True
# 47337  18086.0  1321649  6.265000          23         olive      True
# 33933  18086.0  1611404  4.698750           6      parakeet      True
# 41914  18086.0  1231466  4.952747           6      chestnut      True
# 47944  18086.0  1250519  6.265000          16   thundergrey      True
# 47006  18086.0   406209  6.265000           7    strawberry      True
# 45583  18086.0   587051  5.951750           6    strawberry      True
# 47005  18086.0   407897  6.265000           8          gold      True
# 47007  18086.0   410013  6.265000           9          gold      True
# 28705  18086.0  1613951  3.631831           7  coralsunrise      True
# ...
