# %%
import requests
url = 'https://public.api.cryptokitties.co/v1/signup'
payload = "{\n  \"id\": \"{{current_user_id}}\",\n  \"firstName\": \"Crypto\",\n  \"lastName\": \"Kitty\",\n  \"email\": \"email@gmail.com\",\n  \"password\": \"password\"\n}"
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
  '': ''
}
response = requests.request('POST', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-36cd2a63dc73> in <module>
#       7   '': ''
#       8 }
# ----> 9 response = requests.request('POST', url, headers = headers, data = payload, allow_redirects=False)
#      10 print(response.text)
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# ...

# %%
import requests
url = 'https://public.api.cryptokitties.co/v1/kitties?price=10-100'
headers = {
    'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
    'Content-Type': 'application/json'
}
payload = {}
response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# {"limit":12,"offset":0,"kitties":[],"total":0}

# %%
import requests
import logging

logging.basicConfig()
# logging.getLogger().setLevel(logging.DEBUG)
# requests_log = logging.getLogger("requests.packages.urllib3")
# requests_log.setLevel(logging.DEBUG)
# requests_log.propagate = True

# url = 'https://public.api.cryptokitties.co/v1/signup'
# url = 'https://public.api.cryptokitties.co/v1/kitties?is_prestige=true'
url = 'https://public.api.cryptokitties.co/v1/kitties/1143362'
# url = 'https://public.api.cryptokitties.co/v1/kitties?include=sale&price=80000000000000000-1000000000000000000&orderBy=current_price&limit=50&offset=0&orderDirection=asc'
# 0.08 to 8 eth
# url = 'https://public.api.cryptokitties.co/v1/kitties?orderBy=current_price'
# url = 'https://public.api.cryptokitties.co/v1/kitties?price=1-10000000000000000'
# url = 'https://public.api.cryptokitties.co/v1/kitties?orderBy=generation'
# payload = "{\n  \"id\": \"{{current_user_id}}\",\n  \"firstName\": \"Crypto\",\n  \"lastName\": \"Kitty\",\n  \"email\": \"dylanbedetti1@gmail.com\",\n  \"password\": \"DylanBed01\"\n}"
payload = {}
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
}

response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# {"id":1143362,"name":"KITT-E","bio":"Greetings, friend! I am #{name} the RoboKitty, the world's most adorable catputer and most powerful purrcessor! *Yawn* Oh, excuse me! I'm a little drained. -34zqQE vAoKZ2 aW1fD2 r42635 WBn6WT NB3Pyc GSs3ug wHiTrY bZ6kDM kf8qsy H3swiP nv4BQw CzZaV-","image_url":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1143362.png","image_url_cdn":"https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1143362.png","image_url_png":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1143362.png","image_path":"","generation":1,"created_at":"2018-11-01T02:49:27Z","color":"parakeet","is_fancy":true,"is_exclusive":false,"fancy_type":"KITT-E","language":"en","enhanced_cattributes":[],"status":{"cooldown":1456858359357,"cooldown_index":0,"is_ready":true,"is_gestating":false},"purrs":{"count":0,"is_purred":false},"watchlist":{"count":0,"is_watchlisted":false},"hatched":true,"is_prestige":false,"prestig
# ...

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "kitties": [
#         {
#             "auction": {
#                 "current_price": "1000000000000000000",
#                 "duration": "2592000000",
#                 "end_price": "1000000000000000000",
#                 "end_time": "2018-02-08 04:47:21+00",
#                 "id": 1020881,
#                 "seller": {
#                     "address": "0x64301759342a1470d569838ce7a6ad1e7ed2ef06"
#                 },
#                 "start_price": "990000000000000000",
#                 "start_time": "2018-01-09 04:47:21+00",
#                 "status": "open",
#                 "type": "sale"
#             },
#             "bio": "Sup playa! I'm #{name}. I want to live in a world where people believe the world is flat. My friends describe me as \"gullible.\" It's... accurate. I look forward to grooming with you.",
#             "color": "thundergrey",
#             "created_at": "2018-01-09T03:11:52Z",
#             "enhanced_cattributes": [
#                 {
# ...

# %%
import io
with io.open("Output.txt", "w", encoding="utf-8") as f:
    f.write(response.text)

# %%
import requests 

r = requests.get("https://etherscan.io/tokentxns-nft?a=0xb1690c08e213a35ed9bab7b318de14420fb57d8c")
r.text
# Out:
# '\n<!doctype html>\n<html lang="en">\n<head><title>\r\n\tEthereum Non Fungible Tokens (NFT) - [ERC-721] - Transfers\r\n</title><meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="Description" content="List of ERC721 Token transaction of the Ethereum Blockchain on Etherscan" /><meta name="author" content="etherscan.io" /><meta name="keywords" content="ethereum, explorer, ether, search, blockchain, crypto, currency" /><meta name="format-detection" content="telephone=no" /><script src="/cdn-cgi/apps/head/4wF8T_csPHk5U5Lb4Ye_MOdzMxk.js"></script><link rel="shortcut icon" href="/images/favicon2.ico" /><link rel="stylesheet" href="/assets/vendor/font-awesome/css/fontawesome-all.min.css?v=0.5.1.0" /><link rel="stylesheet" href="/assets/vendor/animate.css/animate.min.css" /><link rel="stylesheet" href="/assets/vendor/hs-megamenu/src/hs.megamenu.css?v=0.5.1.0" /><link rel="stylesheet" href="/assets/vendor/malihu-custom-sc
# ...

# %%
from lxml import etree, html

document_root = html.fromstring(r.text)
print(etree.tostring(document_root, encoding='unicode', pretty_print=True))
# Out:
# <html lang="en">
# <head><title>&#13;
# 	Ethereum Non Fungible Tokens (NFT) - [ERC-721] - Transfers&#13;
# ...
