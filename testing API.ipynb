# %%
import requests
url = 'https://public.api.cryptokitties.co/v1/signup'
payload = "{\n  \"id\": \"{{current_user_id}}\",\n  \"firstName\": \"Crypto\",\n  \"lastName\": \"Kitty\",\n  \"email\": \"email@gmail.com\",\n  \"password\": \"password\"\n}"
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
  '': ''
}
response = requests.request('POST', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-36cd2a63dc73> in <module>
#       7   '': ''
#       8 }
# ----> 9 response = requests.request('POST', url, headers = headers, data = payload, allow_redirects=False)
#      10 print(response.text)
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     601                                                   timeout=timeout_obj,
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#     605             # If we're going to release the connection in ``finally:``, then
#
# c:\users\dylan\anaconda3\envs\kitties\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353             conn.request_chunked(method, url, **httplib_request_kw)
#     354         else:
# --> 355             conn.request(method, url, **httplib_request_kw)
#     356
#     357         # Reset the timeout for the recv() on the socket
#
# c:\users\dylan\anaconda3\envs\kitties\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\users\dylan\anaconda3\envs\kitties\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1278
#    1279         for hdr, value in headers.items():
# -> 1280             self.putheader(hdr, value)
#    1281         if isinstance(body, str):
#    1282             # RFC 2616 Section 3.7.1 says that text default has a
#
# c:\users\dylan\anaconda3\envs\kitties\lib\http\client.py in putheader(self, header, *values)
#    1205
#    1206         if not _is_legal_header_name(header):
# -> 1207             raise ValueError('Invalid header name %r' % (header,))
#    1208
#    1209         values = list(values)
#
# ValueError: Invalid header name b''

# %%
import requests
url = 'https://public.api.cryptokitties.co/v1/kitties?price=10-100'
headers = {
    'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
    'Content-Type': 'application/json'
}
payload = {}
response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# {"limit":12,"offset":0,"kitties":[],"total":0}

# %%
import requests
# url = 'https://public.api.cryptokitties.co/v1/signup'
# url = 'https://public.api.cryptokitties.co/v1/kitties?is_prestige=true'
url = 'https://public.api.cryptokitties.co/v1/kitties/1546975'
# url = 'https://public.api.cryptokitties.co/v1/kitties?orderBy=generation'
# payload = "{\n  \"id\": \"{{current_user_id}}\",\n  \"firstName\": \"Crypto\",\n  \"lastName\": \"Kitty\",\n  \"email\": \"dylanbedetti1@gmail.com\",\n  \"password\": \"DylanBed01\"\n}"
payload = {}
headers = {
  'x-api-token': 'w-5V-v6V__trBl7yxGMXnwhLiGkq-03XnCVNaKePPd4',
  'Content-Type': 'application/json',
}
response = requests.request('GET', url, headers = headers, data = payload, allow_redirects=False)
print(response.text)
# Out:
# {"id":1546975,"name":"Lieutenant Scrummywhoopsie","bio":"Yowza! Allow me to introduce myself. I am #{name} and I am very well known for sculpting my guns and playing the tuba. I'm descended from Hello Kitty. Call my agent if you need me for anything outside of breeding.","image_url":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.svg","image_url_cdn":"https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.svg","image_url_png":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.png","image_path":"","generation":1,"created_at":"2019-04-26T05:37:42Z","color":"dahlia","is_fancy":false,"is_exclusive":false,"fancy_type":null,"language":"en","enhanced_cattributes":[{"type":"eyes","description":"thicccbrowz","position":-1,"kittyId":1546975},{"type":"mouth","description":"moue","position":629,"kittyId":1145427},{"type":"pattern","description":"mittens","position":1317,"kittyId":1546975},{"type":"body","description":"koladiviya","position":7884,"kittyId":1145427},{"type":"colorprimary","description":"bananacream","position":9043,"kittyId":1145427},{"type":"colorsecondary","description":"egyptiankohl","position":9743,"kittyId":1546975},{"type":"colortertiary","description":"cashewmilk","position":5031,"kittyId":1145427},{"type":"coloreyes","description":"dahlia","position":5679,"kittyId":1145427}],"status":{"cooldown":1454330539174,"cooldown_index":0,"is_ready":true,"is_gestating":false},"purrs":{"count":1,"is_purred":false},"watchlist":{"count":0,"is_watchlisted":false},"hatched":true,"is_prestige":false,"prestige_type":null,"prestige_ranking":null,"fancy_ranking":null,"prestige_time_limit":null,"auction":{},"matron":{"id":1145427,"name":"Max Emoswoggle","image_url":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.svg","image_url_cdn":"https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.svg","image_url_png":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.png","generation":0,"created_at":"2018-11-02T06:06:47Z","color":"dahlia","is_fancy":false,"is_exclusive":false,"language":"en","status":{"cooldown":1557341370153,"cooldown_index":12,"is_ready":true,"is_gestating":false},"owner":{"address":"0x68b42e44079d1d0a4a037e8c6ecd62c48967e69f"}},"sire":{"id":1218422,"name":"Dreggo","image_url":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png","image_url_cdn":"https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png","image_url_png":"https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png","generation":0,"created_at":"2018-11-26T16:14:04Z","color":"dahlia","is_fancy":true,"is_exclusive":false,"fancy_type":"Dreggo","language":"en","status":{"cooldown":1557566821524,"cooldown_index":13,"is_ready":true,"is_gestating":false},"owner":{"address":"0x68b42e44079d1d0a4a037e8c6ecd62c48967e69f"}},"owner":{"address":"0x1f38ebcffb0be993b981225a917aaa8a6d6a4e52"}}

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "auction": {},
#     "bio": "Yowza! Allow me to introduce myself. I am #{name} and I am very well known for sculpting my guns and playing the tuba. I'm descended from Hello Kitty. Call my agent if you need me for anything outside of breeding.",
#     "color": "dahlia",
#     "created_at": "2019-04-26T05:37:42Z",
#     "enhanced_cattributes": [
#         {
#             "description": "thicccbrowz",
#             "kittyId": 1546975,
#             "position": -1,
#             "type": "eyes"
#         },
#         {
#             "description": "moue",
#             "kittyId": 1145427,
#             "position": 629,
#             "type": "mouth"
#         },
#         {
#             "description": "mittens",
#             "kittyId": 1546975,
#             "position": 1317,
#             "type": "pattern"
#         },
#         {
#             "description": "koladiviya",
#             "kittyId": 1145427,
#             "position": 7884,
#             "type": "body"
#         },
#         {
#             "description": "bananacream",
#             "kittyId": 1145427,
#             "position": 9043,
#             "type": "colorprimary"
#         },
#         {
#             "description": "egyptiankohl",
#             "kittyId": 1546975,
#             "position": 9743,
#             "type": "colorsecondary"
#         },
#         {
#             "description": "cashewmilk",
#             "kittyId": 1145427,
#             "position": 5031,
#             "type": "colortertiary"
#         },
#         {
#             "description": "dahlia",
#             "kittyId": 1145427,
#             "position": 5679,
#             "type": "coloreyes"
#         }
#     ],
#     "fancy_ranking": null,
#     "fancy_type": null,
#     "generation": 1,
#     "hatched": true,
#     "id": 1546975,
#     "image_path": "",
#     "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.svg",
#     "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.svg",
#     "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1546975.png",
#     "is_exclusive": false,
#     "is_fancy": false,
#     "is_prestige": false,
#     "language": "en",
#     "matron": {
#         "color": "dahlia",
#         "created_at": "2018-11-02T06:06:47Z",
#         "generation": 0,
#         "id": 1145427,
#         "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.svg",
#         "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.svg",
#         "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1145427.png",
#         "is_exclusive": false,
#         "is_fancy": false,
#         "language": "en",
#         "name": "Max Emoswoggle",
#         "owner": {
#             "address": "0x68b42e44079d1d0a4a037e8c6ecd62c48967e69f"
#         },
#         "status": {
#             "cooldown": 1557341370153,
#             "cooldown_index": 12,
#             "is_gestating": false,
#             "is_ready": true
#         }
#     },
#     "name": "Lieutenant Scrummywhoopsie",
#     "owner": {
#         "address": "0x1f38ebcffb0be993b981225a917aaa8a6d6a4e52"
#     },
#     "prestige_ranking": null,
#     "prestige_time_limit": null,
#     "prestige_type": null,
#     "purrs": {
#         "count": 1,
#         "is_purred": false
#     },
#     "sire": {
#         "color": "dahlia",
#         "created_at": "2018-11-26T16:14:04Z",
#         "fancy_type": "Dreggo",
#         "generation": 0,
#         "id": 1218422,
#         "image_url": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png",
#         "image_url_cdn": "https://img.cn.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png",
#         "image_url_png": "https://img.cryptokitties.co/0x06012c8cf97bead5deae237070f9587f8e7a266d/1218422.png",
#         "is_exclusive": false,
#         "is_fancy": true,
#         "language": "en",
#         "name": "Dreggo",
#         "owner": {
#             "address": "0x68b42e44079d1d0a4a037e8c6ecd62c48967e69f"
#         },
#         "status": {
#             "cooldown": 1557566821524,
#             "cooldown_index": 13,
#             "is_gestating": false,
#             "is_ready": true
#         }
#     },
#     "status": {
#         "cooldown": 1454330539174,
#         "cooldown_index": 0,
#         "is_gestating": false,
#         "is_ready": true
#     },
#     "watchlist": {
#         "count": 0,
#         "is_watchlisted": false
#     }
# }
